# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
# * Your analysis here ...

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import seaborn as sns
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_data=pd.merge(study_results,mouse_metadata, how="outer", on="Mouse ID")
# Display the data table for preview
combined_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
print(combined_data["Mouse ID"].nunique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicated_mice=combined_data[combined_data.duplicated(subset=["Mouse ID","Timepoint"],keep=False)]
duplicated_mice
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
#
#         Sex  Age_months  Weight (g)
# 860  Female          21          26
# 861  Female          21          26
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 
combined_data[combined_data["Mouse ID"]=="g989"]
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse  IDs.
combined_data=combined_data[combined_data["Mouse ID"]!="g989"]
combined_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
print(combined_data["Mouse ID"].nunique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# %%
#Maryam's
Mean_tumor_vol=combined_data.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]

Median_tumor_vol=combined_data.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]

Tumor_vol_variance=combined_data.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]

Tumor_vol_std_Dev=combined_data.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]

Tumor_vol_std_Err=combined_data.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]

Summary_Stat_df=pd.DataFrame({
                            "Mean Tumor Volume":Mean_tumor_vol,
                            "Median Tumor Volume":Median_tumor_vol,
                            "Tumor Volume Variance":Tumor_vol_variance,
                            "Tumor Volume Std.Dev.":Tumor_vol_std_Dev,
                            "Tumor Volume Std. Err.":Tumor_vol_std_Err
                            })

Summary_Stat_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std.Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
combined_data.groupby("Drug Regimen").agg({"Tumor Volume (mm3)": ['mean', 'median','var','std','sem']})
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.

# %%
#Maryam
#creating a new DataFrame grouped by Drug Regimen
Drug_data_df=pd.DataFrame(combined_data.groupby("Drug Regimen").count()["Mouse ID"])

Drug_data_df.plot(kind="bar",)
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Unique Mice Tested')
plt.show()

# %%
# Generate a bar plot showing the total number of unqiue mice tested on each drug regimen using using pyplot.

# %%
Drug_reg=Summary_Stat_df.index.tolist()
Reg_count=(combined_data.groupby("Drug Regimen").count()["Mouse ID"]).tolist()

# %%
x_axis=np.arange(0,len(Drug_reg))

tick_locations = []
for x in x_axis:
        tick_locations.append(x)
        
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Unique Mice Tested") 

plt.xlim(-0.75, len(Drug_reg)-.25)
plt.ylim(0, max(Reg_count) + 5)

plt.bar(x_axis,Reg_count, color="b",alpha=0.75, align="center")
plt.xticks(tick_locations,Drug_reg,rotation=45)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

gender_df=pd.DataFrame(combined_data.groupby(["Sex"]).count().reset_index())
gender_df = gender_df.rename(columns={"Mouse ID": "gender distribution count"})


plt.figure(figsize=(10,6))
ax1 = plt.subplot(121, aspect='equal')
gender_df.plot(kind='pie', y = "gender distribution count", ax=ax1, autopct='%1.1f%%', 
               startangle=180, shadow=False,labels=gender_df['Sex'], legend = False, fontsize=16)
# Out:
# <AxesSubplot:ylabel='gender distribution count'>

# %%
## Generate a pie plot showing the distribution of female versus male mice using pyplot
Gender_count=combined_data["Sex"].value_counts().tolist()
Gender_count
# Out:
# [958, 922]

# %%
labels=["Males","Females"]
colors=["blue","orange"]
explode=(0,0)

# %%
plt.pie(Gender_count,explode=explode, labels=labels, colors=colors, 
        autopct="%1.1f%%", shadow=True, startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f99e3f40c70>,
# ...
#  [Text(0.033082014082615095, -1.0995024239828841, 'Males'),
#   Text(-0.03308201408261496, 1.0995024239828841, 'Females')],
#  [Text(0.018044734954153686, -0.5997285948997549, '51.0%'),
#   Text(-0.018044734954153614, 0.5997285948997549, '49.0%')])

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
Cap_df = combined_data.loc[combined_data["Drug Regimen"] == "Capomulin",:]
Ram_df =combined_data.loc[combined_data["Drug Regimen"] == "Ramicane", :]
Inf_df = combined_data.loc[combined_data["Drug Regimen"] == "Infubinol", :]
ceft_df = combined_data.loc[combined_data["Drug Regimen"] == "Ceftamin", :]


#Capomulin
Cap_last = Cap_df.groupby('Mouse ID').max()['Timepoint']
Cap_vol = pd.DataFrame(Cap_last)
Cap_merge = pd.merge(Cap_vol, combined_data, on=("Mouse ID","Timepoint"),how="left")
Cap_merge.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128         45           38.982878                 2    Capomulin
# 1     b742         45           38.939633                 0    Capomulin
# 2     f966         20           30.485985                 0    Capomulin
# 3     g288         45           37.074024                 1    Capomulin
# 4     g316         45           40.159220                 2    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male           7          21
# 2    Male          16          17
# 3    Male           3          19
# 4  Female          22          22

# %%
#Ceftamin
ceft_last = ceft_df.groupby('Mouse ID').max()['Timepoint']
ceft_vol = pd.DataFrame(ceft_last)
ceft_merge = pd.merge(ceft_vol, combined_data, on=("Mouse ID","Timepoint"),how="left")
ceft_merge.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a275         45           62.999356                 3     Ceftamin
# 1     b447          0           45.000000                 0     Ceftamin
# 2     b487         25           56.057749                 1     Ceftamin
# 3     b759         30           55.742829                 1     Ceftamin
# 4     f436         15           48.722078                 2     Ceftamin
#
#       Sex  Age_months  Weight (g)
# 0  Female          20          28
# 1    Male           2          30
# 2  Female           6          28
# 3  Female          12          25
# 4  Female           3          25

# %%
Ram_last = Ram_df.groupby('Mouse ID').max()['Timepoint']
Ram_vol = pd.DataFrame(Ram_last)
Ram_merge = pd.merge(Rap_vol, combined_data, on=("Mouse ID","Timepoint"),how="left")
Ram_merge.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a411         45           38.407618                 1     Ramicane
# 1     a444         45           43.047543                 0     Ramicane
# 2     a520         45           38.810366                 1     Ramicane
# 3     a644         45           32.978522                 1     Ramicane
# 4     c458         30           38.342008                 2     Ramicane
#
#       Sex  Age_months  Weight (g)
# 0    Male           3          22
# 1  Female          10          25
# 2    Male          13          21
# 3  Female           7          17
# 4  Female          23          20

# %%
Inf_last = Inf_df.groupby('Mouse ID').max()['Timepoint']
Inf_vol = pd.DataFrame(Inf_last)
Inf_merge = pd.merge(Inf_vol, combined_data, on=("Mouse ID","Timepoint"),how="left")
Inf_merge.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a203         45           67.973419                 2    Infubinol
# 1     a251         45           65.525743                 1    Infubinol
# 2     a577         30           57.031862                 2    Infubinol
# 3     a685         45           66.083066                 3    Infubinol
# 4     c139         45           72.226731                 2    Infubinol
#
#       Sex  Age_months  Weight (g)
# 0  Female          20          23
# 1  Female          21          25
# 2  Female           6          25
# 3    Male           8          30
# 4    Male          11          28

# %%
Cap_tomur = Cap_merge["Tumor Volume (mm3)"]
Ram_tomur =Rap_merge["Tumor Volume (mm3)"]
Inf_tomur = Inf_merge["Tumor Volume (mm3)"]
ceft_tomur = ceft_merge["Tumor Volume (mm3)"]

tumors_list=[Cap_tomur,Ram_tomur,Inf_tomur,ceft_tomur] 

for tomurs in tumors_list:
    quartiles =tomurs.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f"The lower quartile of Infubinol tumors is: {lowerq}")
    print(f"The upper quartile of Infubinol tumors is: {upperq}")
    print(f"The interquartile range of Infubinol tumors is: {iqr}")
    print(f"The median of Infubinol tumors is: {quartiles[0.5]} ")

    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)


    print(f"Values below {lower_bound} could be outliers.")
    print(f"Values above {upper_bound} could be outliers.")
    print(f"-----------------------------------------------")
# Out:
# The lower quartile of Infubinol tumors is: 32.37735684
# The upper quartile of Infubinol tumors is: 40.1592203
# The interquartile range of Infubinol tumors is: 7.781863460000004
# The median of Infubinol tumors is: 38.1251644
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.
# -----------------------------------------------
# The lower quartile of Infubinol tumors is: 32.37735684
# The upper quartile of Infubinol tumors is: 40.1592203
# The interquartile range of Infubinol tumors is: 7.781863460000004
# The median of Infubinol tumors is: 38.1251644
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.
# -----------------------------------------------
# The lower quartile of Infubinol tumors is: 54.04860769
# The upper quartile of Infubinol tumors is: 65.52574285
# The interquartile range of Infubinol tumors is: 11.477135160000003
# The median of Infubinol tumors is: 60.16518046
# ...

# %%
tomour_list=[Cap_tumors,Ram_tumor,Inf_tumor,ceft_tumor]
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

fig1, ax1 = plt.subplots()
ax1.set_title("final tumor volume of each mouse across four regimens of interest")
ax1.set_ylabel("Final Tumor Volume (mm3)")

ax1.boxplot(tomour_list,labels=treatment_list)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f99c4ddb340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f99c4ddbd00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f99c4dc5ee0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f99c4dea040>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f99c4dea3a0>,
# ...
#  'means': []}

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
line_graph_df=Cap_df.loc[Cap_df["Mouse ID"]=="f966",:]
line_graph_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 1878     f966          0           45.000000                 0    Capomulin
# 1879     f966          5           38.796474                 0    Capomulin
# 1880     f966         10           35.624403                 0    Capomulin
# 1881     f966         15           32.623003                 0    Capomulin
# 1882     f966         20           30.485985                 0    Capomulin
#
#        Sex  Age_months  Weight (g)
# 1878  Male          16          17
# 1879  Male          16          17
# 1880  Male          16          17
# 1881  Male          16          17
# 1882  Male          16          17

# %%
x_axis=line_graph_df["Timepoint"]
tumor_vol=line_graph_df["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots()
plt.title('Capomulin treatmeant of mouse f966',fontsize =14)
plt.plot(x_axis, tumor_vol,linewidth=2, markersize=15, label="Fahreneit")
plt.xlabel('Timepoint (Days)',fontsize =14)
plt.ylabel('Tumor Volume (mm3)',fontsize =14)

plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
fig1, ax1 = plt.subplots()
avg_cap_vol =Cap_df.groupby(['Mouse ID']).mean()

marker_size=15
plt.scatter(avg_cap_vol['Weight (g)'],avg_cap_vol['Tumor Volume (mm3)'])
plt.title('Mouse Weight Versus Average Tumor Volume',fontsize =25)
plt.xlabel('Weight (g)',fontsize =14)
plt.ylabel('Averag Tumor Volume (mm3)',fontsize =14)



plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
corr=round(st.pearsonr(avg_cap_vol['Weight (g)'],avg_cap_vol['Tumor Volume (mm3)'])[0],2)
print(f"The correlation between mouse weight and average tumor volume is {corr}")
# Out:
# The correlation between mouse weight and average tumor volume is 0.84

# %%
LinregressResult=st.linregress(avg_cap_vol['Weight (g)'],avg_cap_vol['Tumor Volume (mm3)'])
LinregressResult
# Out:
# LinregressResult(slope=0.9544396890241045, intercept=21.552160532685015, rvalue=0.8419363424694718, pvalue=1.3225722434712642e-07, stderr=0.1275435903320134, intercept_stderr=2.590987686768349)

# %%
slope = 0.9544396890241045
intercept = 21.552160532685015

# %%
y_values = avg_cap_vol['Weight (g)']*slope+intercept
plt.scatter(avg_cap_vol['Weight (g)'],avg_cap_vol['Tumor Volume (mm3)'])
plt.plot(avg_cap_vol['Weight (g)'],y_values,color="red")
plt.xlabel('Weight(g)')
plt.ylabel('Average Tumore Volume (mm3)')

plt.savefig('linearregression')
plt.show()
